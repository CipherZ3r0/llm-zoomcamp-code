# %%
from sqlitesearch import TextSearchIndex
    
sqlite_index = TextSearchIndex(
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"],
    db_path="faq.db"
)

# %%
sqlite_index.count()
# Out:
# 237

# %%
results = sqlite_index.search("Can I still join the course after it started?", num_results=5)
[doc["question"] for doc in results]
# Out:
# ['I just discovered the course. Can I still join?',
#  'I just discovered the course. Can I still join?',
#  'I just discovered the course. Can I still join?',
#  'I missed the first homework - can I still get a certificate?',
#  'I missed the first homework - can I still get a certificate?']

# %%
import os
import sys
sys.path.append("..")

from rag_helper import RAGBase
from groq import Groq

groq_client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),
)

assistant = RAGBase(
    index=sqlite_index,
    llm_client=groq_client,
)

# %%
answer = assistant.rag("Can I still join the course after it started?")
print(answer)
# Out:
# ChatCompletion(id='chatcmpl-a3441853-788e-456f-8eda-2e86c222697d', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Yes, you can still join the course after it started, but if you want to receive a certificate, you need to submit your project while submissions are still being accepted. However, please note that you must be part of a "live" cohort to be eligible for a certificate, as self-paced mode does not qualify for certification.', role='assistant', annotations=None, executed_tools=None, function_call=None, reasoning=None, tool_calls=None))], created=1781378244, model='llama-3.3-70b-versatile', object='chat.completion', mcp_list_tools=None, service_tier='on_demand', system_fingerprint='fp_3272ea2d91', usage=CompletionUsage(completion_tokens=67, prompt_tokens=402, total_tokens=469, completion_time=0.187429041, completion_tokens_details=None, prompt_time=0.020677452, prompt_tokens_details=None, queue_time=0.227361378, total_time=0.208106493), usage_breakdown=None, x_groq=XGroq(id='req_01kv16nqbnf0n8jyenaqg2c8nf', debug=None, seed=1019954711, usage=None))

# %%
sqlite_index.close()
